# %% [markdown]
# # InternViT Classifier - threshold selection

# %% [markdown]
# ## 0) Setup

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from epsutils.training.performance_curve_calculator import PerformanceCurveCalculator, PerformanceCurveType

ROOT_JSONL_DIR = "/home/arjun/tmp/classifier_attn_pool_val_data_08312025"
TARGET_PRECISION = 0.90

# %% [markdown]
# ## 1) Read raw .jsonl data

# %%
# Find all jsonl files in the root directory.
jsonl_files = []
for fname in os.listdir(ROOT_JSONL_DIR):
    if fname.endswith('.jsonl'):
        jsonl_files.append(fname.split(".")[0])

print("Num labels:", len(jsonl_files))
# Out:
# Num labels: 278

# %%
output_map = {}
threshold_info = []
no_findings_stats = {}

for jsonl_file in jsonl_files:

    # Get body part and label from the jsonl file name.
    split = jsonl_file.split("release_intern_vit_classifier-training-on-")[1].split("_")
    body_part = split[0]
    label = "_".join(split[1:])

    # Create a new entry in the output map for the body part if it doesn't exist.
    if body_part not in output_map:
        output_map[body_part] = {}

    data = []
    fp = os.path.join(ROOT_JSONL_DIR, f"{jsonl_file}.jsonl")
    with open(fp, "r") as f:
        for line in f:
            data.append(json.loads(line))

    # Get predictions and labels.
    y_true = [int(d["target"][0]) for d in data]
    y_pred = [float(d["prob"]) for d in data]
    assert len(y_true) == len(y_pred)

    # Calculate the PR curve points.
    curve_calculator = PerformanceCurveCalculator()
    curve_data = curve_calculator.compute_curve(
        PerformanceCurveType.PRC, y_true, y_pred
    )
    precision = curve_data["precision"]
    recall = curve_data["recall"]
    thresholds = curve_data["thresholds"]

    # Find the threshold that gives the target precision.
    idx = np.argmax(precision >= TARGET_PRECISION)
    if idx == len(precision) - 1:
        # Find the idx where threshold is closest to 0.5
        idx = np.argmin(np.abs(thresholds - 0.5))
        print(
            f"No threshold found for {body_part} - {label} at precision={TARGET_PRECISION}. Using threshold closest to 0.5 (t={thresholds[idx]})"
        )

    # Store threshold info.
    threshold_info.append(
        {
            "body_part": body_part,
            "label": label,
            "threshold": float(thresholds[idx]),
            "precision": float(precision[idx]),
            "recall": float(recall[idx]),
            "num_samples": int(len(y_true)),
            "num_positives": int(sum(y_true)),
        }
    )
    output_map[body_part][label] = float(thresholds[idx])

    # For 'no_findings' labels, calculate recall & 90/95/99/99.9% precisions
    if label == "no_findings":
        # For each target precision, find the threshold and recall at that precision
        target_precisions = [0.90, 0.95, 0.99, 0.999]
        stats = {}
        for tp in target_precisions:
            idx_tp = np.argmax(precision >= tp)
            stats[f"precision_{int(tp*1000)/10:.1f}%"] = {
                "threshold": float(thresholds[idx_tp]),
                "precision": float(precision[idx_tp]),
                "recall": float(recall[idx_tp]),
            }
        # Also store the full recall array for this label if needed
        no_findings_stats[body_part] = {
            "label": label,
            "num_samples": int(len(y_true)),
            "num_positives": int(sum(y_true)),
            "recall_at_precisions": stats,
        }
# Out:
# No threshold found for c-spine - cervical_spine_alignment at precision=0.9. Using threshold closest to 0.5 (t=0.498046875)
# No threshold found for l-spine - schmorl's_node at precision=0.9. Using threshold closest to 0.5 (t=0.5)

# %% [markdown]
# ## 2) Compute statistics on classifier performance

# %% [markdown]
# ### Recall @ fixed precision metrics

# %%
recalls = [t["recall"] for t in threshold_info]
plt.figure(figsize=(8, 5))
plt.hist(recalls, bins=50, edgecolor='black', alpha=0.7)
plt.title(f'Distribution of Recall Values at fixed precision={TARGET_PRECISION}')
plt.xlabel('Recall')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

import numpy as np

# Calculate useful statistics for recall values
recalls_np = np.array(recalls)
mean_recall = np.mean(recalls_np)
median_recall = np.median(recalls_np)
min_recall = np.min(recalls_np)
max_recall = np.max(recalls_np)
std_recall = np.std(recalls_np)
percent_above_99 = np.mean(recalls_np >= 0.99) * 100
percent_above_95 = np.mean(recalls_np >= 0.95) * 100
percent_above_90 = np.mean(recalls_np >= 0.90) * 100
percent_above_75 = np.mean(recalls_np >= 0.75) * 100
percent_below_5 = np.mean(recalls_np < 0.05) * 100
percent_below_10 = np.mean(recalls_np < 0.10) * 100
percent_below_25 = np.mean(recalls_np < 0.25) * 100
percent_below_50 = np.mean(recalls_np < 0.50) * 100

print("Recall Statistics at fixed precision={:.2f}:".format(TARGET_PRECISION))
print(f"  Mean recall:    {mean_recall:.4f}")
print(f"  Median recall:  {median_recall:.4f}")
print(f"  Min recall:     {min_recall:.4f}")
print(f"  Max recall:     {max_recall:.4f}")
print(f"  Std deviation:  {std_recall:.4f}")
print(f"  Percent above...")
print(f"    >= 0.99:      {percent_above_99:.1f}%")
print(f"    >= 0.95:      {percent_above_95:.1f}%")
print(f"    >= 0.90:      {percent_above_90:.1f}%")
print(f"    >= 0.75:      {percent_above_75:.1f}%")
print(f"  Percent below...")
print(f"    < 0.05:       {percent_below_5:.1f}%")
print(f"    < 0.10:       {percent_below_10:.1f}%")
print(f"    < 0.25:       {percent_below_25:.1f}%")
print(f"    < 0.50:       {percent_below_50:.1f}%")
# Out:
# Recall Statistics at fixed precision=0.90:
#   Mean recall:    0.5484
#   Median recall:  0.5436
#   Min recall:     0.0007
#   Max recall:     0.9984
#   Std deviation:  0.2798
#   Percent above...
#     >= 0.99:      2.5%
#     >= 0.95:      7.6%
#     >= 0.90:      13.3%
#     >= 0.75:      26.6%
#   Percent below...
#     < 0.05:       5.8%
#     < 0.10:       8.6%
#     < 0.25:       16.5%
#     < 0.50:       43.2%

# %% [markdown]
# ### 'No findings' high-precision stats.

# %%
# For each body part, output recall at 90/95/99/99.9% precision for the 'no_findings' label using the new no_findings_stats structure

# Define the precision keys and their display names
precision_keys = [
    "precision_90.0%",
    "precision_95.0%",
    "precision_99.0%",
    "precision_99.9%",
]
precision_display = [
    "Recall@P>=90.0%",
    "Recall@P>=95.0%",
    "Recall@P>=99.0%",
    "Recall@P>=99.9%",
]

print("Recall for 'no_findings' at various precision levels by body part:")
header = ["Body Part"] + precision_display
row_format = "{:<20}" + "{:>18}" * len(precision_keys)
print(row_format.format(*header))

for body_part in sorted(no_findings_stats.keys()):
    stats = no_findings_stats[body_part]
    recall_at_precisions = stats.get("recall_at_precisions", {})
    row = [body_part]
    for key in precision_keys:
        recall_info = recall_at_precisions.get(key, None)
        if recall_info is not None and "recall" in recall_info and recall_info["recall"] is not None:
            row.append(f"{recall_info['recall']:.4f}")
        else:
            row.append("N/A")
    print(row_format.format(*row))
# Out:
# Recall for 'no_findings' at various precision levels by body part:
# Body Part              Recall@P>=90.0%   Recall@P>=95.0%   Recall@P>=99.0%   Recall@P>=99.9%
# abdomen                         0.3496            0.0015            0.0015            0.0015
# arm                             0.4485            0.1525            0.0013            0.0013
# c-spine                         0.7480            0.4321            0.1384            0.0189
# chest                           0.5625            0.2551            0.0016            0.0016
# foot                            0.4269            0.0437            0.0020            0.0020
# hand                            0.5374            0.2600            0.0021            0.0021
# head                            0.1231            0.0502            0.0240            0.0240
# l-spine                         0.4965            0.1185            0.0171            0.0126
# leg                             0.6467            0.2474            0.0080            0.0080
# pelvis                          0.3572            0.1532            0.0011            0.0011
# t-spine                         0.4951            0.2524            0.0079            0.0079

# %% [markdown]
# ## 3) Write chosen thresholds to file (and dump raw data to notebook).

# %%
# Write the thresholds to a json file for ingestion by production inference code.
output_fp = "/home/arjun/tmp/classifier_thresholds_by_label.json"
with open(output_fp, "w") as f:
    json.dump(output_map, f, indent=2)
print(f"Thresholds written to {output_fp}")
# Out:
# Thresholds written to /home/arjun/tmp/classifier_thresholds_by_label.json

# %%
for t in threshold_info:
    body_part = t.get("body_part", "N/A")
    label = t.get("label", "N/A")
    threshold = t.get("threshold", "N/A")
    precision = t.get("precision", "N/A")
    recall = t.get("recall", "N/A")
    print(f"Body part: {body_part}, Label: {label} (num_samples={t.get('num_samples', 'N/A')}, num_positives={t.get('num_positives', 'N/A')})")
    print(f"  Threshold: {threshold}")
    print(f"  Precision: {precision}")
    print(f"  Recall:    {recall}")
    print("")
# Out:
# Body part: arm, Label: fracture (num_samples=12896, num_positives=6449)
#   Threshold: 0.349609375
#   Precision: 0.9000882612533098
#   Recall:    0.7906652194138626
#
# Body part: hand, Label: tendon_avulsion_fractures (num_samples=960, num_positives=480)
#   Threshold: 0.66796875
#   Precision: 0.9111111111111111
#   Recall:    0.25625
#
# Body part: l-spine, Label: support_devices (num_samples=16128, num_positives=8067)
#   Threshold: 0.384765625
#   Precision: 0.9002661259662907
#   Recall:    0.8806247675715879
#
# Body part: abdomen, Label: no_findings (num_samples=10752, num_positives=5378)
#   Threshold: 0.70703125
#   Precision: 0.9008145663632008
#   Recall:    0.34957233172182967
#
# Body part: hand, Label: ulnar_variance (num_samples=1088, num_positives=543)
#   Threshold: 0.89453125
#   Precision: 1.0
#   Recall:    0.0055248618784530384
#
# Body part: chest, Label: enlarged_pulmonary_artery (num_samples=1504, num_positives=752)
#   Threshold: 0.453125
#   Precision: 0.9026548672566371
#   Recall:    0.6781914893617021
#
# Body part: abdomen, Label: iud (num_samples=864, num_positives=431)
#   Threshold: 0.0272216796875
#   Precision: 0.9006342494714588
#   Recall:    0.988399071925754
#
# Body part: abdomen, Label: bowel_dilation (num_samples=8736, num_positives=4374)
#   Threshold: 0.451171875
#   Precision: 0.900377358490566
#   Recall:    0.8182441700960219
#
# Body part: l-spine, Label: spina_bifida_occulta (num_samples=672, num_positives=334)
#   Threshold: 0.5625
#   Precision: 0.9347826086956522
#   Recall:    0.12874251497005987
#
# Body part: t-spine, Label: scoliosis (num_samples=10656, num_positives=5330)
#   Threshold: 0.53125
#   Precision: 0.9026315789473685
#   Recall:    0.5791744840525328
#
# Body part: hand, Label: osteophytes (num_samples=3392, num_positives=1700)
#   Threshold: 0.7265625
#   Precision: 0.9001248439450686
#   Recall:    0.42411764705882354
#
# Body part: chest, Label: aortic_elongation_enlargement (num_samples=14816, num_positives=7409)
#   Threshold: 0.6015625
#   Precision: 0.9004127966976264
#   Recall:    0.7065730867863409
#
# Body part: leg, Label: heterotopic_ossification (num_samples=544, num_positives=271)
#   Threshold: 0.609375
#   Precision: 0.9027777777777778
#   Recall:    0.4797047970479705
#
# Body part: leg, Label: arthritic_changes (num_samples=18944, num_positives=9473)
#   Threshold: 0.73828125
#   Precision: 0.90066456803078
#   Recall:    0.27182518737464373
#
# Body part: arm, Label: foreign_bodies (num_samples=768, num_positives=382)
#   Threshold: 0.3984375
#   Precision: 0.9009009009009009
#   Recall:    0.7853403141361257
#
# Body part: t-spine, Label: levoconvex (num_samples=3840, num_positives=1923)
#   Threshold: 0.65234375
#   Precision: 0.9003880983182406
#   Recall:    0.3619344773790952
#
# Body part: leg, Label: edema (num_samples=992, num_positives=495)
#   Threshold: 0.61328125
#   Precision: 0.9014084507042254
#   Recall:    0.3878787878787879
#
# Body part: foot, Label: synostosis (num_samples=768, num_positives=384)
#   Threshold: 0.46875
#   Precision: 0.9025641025641026
#   Recall:    0.4583333333333333
#
# Body part: c-spine, Label: degenerative_changes (num_samples=27968, num_positives=13984)
#   Threshold: 0.62890625
#   Precision: 0.9002169197396963
#   Recall:    0.6825657894736842
#
# Body part: chest, Label: fracture (num_samples=13632, num_positives=6817)
#   Threshold: 0.51953125
#   Precision: 0.9014666391241479
#   Recall:    0.6401642951444917
#
# Body part: abdomen, Label: uterine_fibroids (num_samples=608, num_positives=303)
#   Threshold: 0.09423828125
#   Precision: 0.9023569023569024
#   Recall:    0.8844884488448845
#
# Body part: abdomen, Label: ileus (num_samples=5216, num_positives=2607)
#   Threshold: 0.6640625
#   Precision: 0.900609756097561
#   Recall:    0.5665515918680476
#
# Body part: chest, Label: pneumonitis (num_samples=2432, num_positives=1218)
#   Threshold: 0.66015625
#   Precision: 0.9010339734121122
#   Recall:    0.5008210180623974
#
# Body part: foot, Label: soft_tissue_calcifications (num_samples=4896, num_positives=2447)
#   Threshold: 0.421875
#   Precision: 0.900709219858156
#   Recall:    0.726604004903964
#
# Body part: leg, Label: bony_mineralization (num_samples=3520, num_positives=1761)
#   Threshold: 0.74609375
#   Precision: 0.9095744680851063
#   Recall:    0.19420783645655879
#
# Body part: c-spine, Label: no_findings (num_samples=9824, num_positives=4913)
#   Threshold: 0.59375
#   Precision: 0.9002939735423812
#   Recall:    0.748015469163444
#
# Body part: l-spine, Label: vertebral_height_loss (num_samples=4096, num_positives=2049)
#   Threshold: 0.65625
#   Precision: 0.9017094017094017
#   Recall:    0.4119082479258175
#
# Body part: foot, Label: tendinous_calcifications (num_samples=1088, num_positives=543)
#   Threshold: 0.51953125
#   Precision: 0.9
#   Recall:    0.5469613259668509
#
# Body part: hand, Label: erosive_change (num_samples=1440, num_positives=718)
#   Threshold: 0.5390625
#   Precision: 0.9004739336492891
#   Recall:    0.5292479108635098
#
# Body part: pelvis, Label: heterotopic_ossification (num_samples=896, num_positives=448)
#   Threshold: 0.28125
#   Precision: 0.9002695417789758
#   Recall:    0.7455357142857143
#
# Body part: foot, Label: foreign_bodies (num_samples=768, num_positives=383)
#   Threshold: 0.404296875
#   Precision: 0.9007633587786259
#   Recall:    0.6161879895561357
#
# Body part: l-spine, Label: postoperative_fusion_changes (num_samples=8032, num_positives=4015)
#   Threshold: 0.0194091796875
#   Precision: 0.9
#   Recall:    0.9930261519302616
#
# Body part: chest, Label: adenopathy (num_samples=2144, num_positives=1070)
#   Threshold: 0.3828125
#   Precision: 0.9009779951100244
#   Recall:    0.688785046728972
#
# Body part: arm, Label: arthritic_changes (num_samples=7808, num_positives=3904)
#   Threshold: 0.72265625
#   Precision: 0.9008379888268156
#   Recall:    0.33043032786885246
#
# Body part: chest, Label: cardiac_devices (num_samples=2528, num_positives=1266)
#   Threshold: 0.0673828125
#   Precision: 0.9005046863734679
#   Recall:    0.9865718799368088
#
# Body part: chest, Label: pneumothorax (num_samples=2080, num_positives=1038)
#   Threshold: 0.275390625
#   Precision: 0.9008579599618685
#   Recall:    0.9104046242774566
#
# Body part: l-spine, Label: fracture (num_samples=832, num_positives=415)
#   Threshold: 0.984375
#   Precision: 1.0
#   Recall:    0.007228915662650603
#
# Body part: pelvis, Label: dislocation (num_samples=736, num_positives=367)
#   Threshold: 0.2041015625
#   Precision: 0.901685393258427
#   Recall:    0.8746594005449592
#
# Body part: arm, Label: bone_lesions (num_samples=1056, num_positives=529)
#   Threshold: 0.53125
#   Precision: 0.9035087719298246
#   Recall:    0.389413988657845
#
# Body part: foot, Label: os_navicularis (num_samples=928, num_positives=464)
#   Threshold: 0.435546875
#   Precision: 0.9014598540145985
#   Recall:    0.5323275862068966
#
# Body part: abdomen, Label: ureteral_calculi (num_samples=4672, num_positives=2335)
#   Threshold: 0.62890625
#   Precision: 0.9017743979721166
#   Recall:    0.6094218415417559
#
# Body part: c-spine, Label: facet_joint_hypertrophy_or_arthropathy (num_samples=8544, num_positives=4273)
#   Threshold: 0.71875
#   Precision: 0.9011735639283508
#   Recall:    0.34144629066229815
#
# Body part: foot, Label: amputation (num_samples=1504, num_positives=750)
#   Threshold: 0.1494140625
#   Precision: 0.9006369426751593
#   Recall:    0.9426666666666667
#
# Body part: pelvis, Label: cam_deformity (num_samples=544, num_positives=271)
#   Threshold: 0.408203125
#   Precision: 0.900523560209424
#   Recall:    0.6346863468634686
#
# Body part: chest, Label: scarring (num_samples=27840, num_positives=13920)
#   Threshold: 0.68359375
#   Precision: 0.9009169289722184
#   Recall:    0.47291666666666665
#
# Body part: leg, Label: ossicles (num_samples=1312, num_positives=654)
#   Threshold: 0.59375
#   Precision: 0.9018181818181819
#   Recall:    0.37920489296636084
#
# Body part: pelvis, Label: soft_tissue_calcifications (num_samples=3904, num_positives=1955)
#   Threshold: 0.54296875
#   Precision: 0.9011725293132329
#   Recall:    0.550383631713555
#
# Body part: chest, Label: arthritis (num_samples=1024, num_positives=511)
#   Threshold: 0.32421875
#   Precision: 0.9009661835748792
#   Recall:    0.7299412915851272
#
# Body part: abdomen, Label: colonic_distension (num_samples=3200, num_positives=1603)
#   Threshold: 0.5234375
#   Precision: 0.9000780640124902
#   Recall:    0.7192763568309419
#
# Body part: pelvis, Label: soft_tissue_swelling (num_samples=448, num_positives=223)
#   Threshold: 0.828125
#   Precision: 0.9
#   Recall:    0.1210762331838565
#
# Body part: hand, Label: soft_tissue_calcifications (num_samples=3296, num_positives=1651)
#   Threshold: 0.5
#   Precision: 0.9010458567980691
#   Recall:    0.6783767413688674
#
# Body part: l-spine, Label: scoliosis (num_samples=32256, num_positives=16128)
#   Threshold: 0.54296875
#   Precision: 0.9007991660875608
#   Recall:    0.6429811507936508
#
# Body part: abdomen, Label: free_air (num_samples=480, num_positives=239)
#   Threshold: 0.53125
#   Precision: 0.9
#   Recall:    0.301255230125523
#
# Body part: l-spine, Label: straightening (num_samples=4832, num_positives=2416)
#   Threshold: 0.70703125
#   Precision: 0.900720576461169
#   Recall:    0.4656456953642384
#
# Body part: l-spine, Label: intervertebral_disc_narrowing (num_samples=38304, num_positives=19153)
#   Threshold: 0.72265625
#   Precision: 0.9008627450980392
#   Recall:    0.2998485876886128
#
# Body part: c-spine, Label: hardware (num_samples=640, num_positives=318)
#   Threshold: 0.30859375
#   Precision: 0.9005681818181818
#   Recall:    0.9968553459119497
#
# Body part: hand, Label: nonunion (num_samples=640, num_positives=319)
#   Threshold: 0.30859375
#   Precision: 0.9042145593869731
#   Recall:    0.7398119122257053
#
# Body part: pelvis, Label: ureteral_calculi (num_samples=2304, num_positives=1152)
#   Threshold: 0.55859375
#   Precision: 0.9008620689655172
#   Recall:    0.9071180555555556
#
# Body part: chest, Label: costophrenic_angle_blunting (num_samples=5856, num_positives=2927)
#   Threshold: 0.58203125
#   Precision: 0.9004451639012545
#   Recall:    0.7601639904338914
#
# Body part: chest, Label: tortuous_aorta (num_samples=23168, num_positives=11582)
#   Threshold: 0.7265625
#   Precision: 0.9016839598571186
#   Recall:    0.45769297185287516
#
# Body part: leg, Label: subchondral_cyst (num_samples=704, num_positives=351)
#   Threshold: 0.41796875
#   Precision: 0.900709219858156
#   Recall:    0.36182336182336183
#
# Body part: arm, Label: no_findings (num_samples=26560, num_positives=13278)
#   Threshold: 0.671875
#   Precision: 0.9007714415368325
#   Recall:    0.44848621780388614
#
# Body part: chest, Label: diaphragmatic_elevation (num_samples=8768, num_positives=4386)
#   Threshold: 0.39453125
#   Precision: 0.9000230361667818
#   Recall:    0.8907888736890105
#
# Body part: chest, Label: hernia (num_samples=1344, num_positives=670)
#   Threshold: 0.16015625
#   Precision: 0.9
#   Recall:    0.926865671641791
#
# Body part: pelvis, Label: pelvic_phleboliths (num_samples=7872, num_positives=3936)
#   Threshold: 0.60546875
#   Precision: 0.9010292953285828
#   Recall:    0.5782520325203252
#
# Body part: abdomen, Label: abnormal_gas_patterns (num_samples=9664, num_positives=4837)
#   Threshold: 0.76171875
#   Precision: 0.9110671936758893
#   Recall:    0.09530700847632831
#
# Body part: l-spine, Label: lumbarization_of_s1 (num_samples=1056, num_positives=527)
#   Threshold: 0.9140625
#   Precision: 1.0
#   Recall:    0.0018975332068311196
#
# Body part: l-spine, Label: aortic_calcifications (num_samples=8288, num_positives=4145)
#   Threshold: 0.7109375
#   Precision: 0.9015025041736227
#   Recall:    0.6513872135102533
#
# Body part: c-spine, Label: straightening (num_samples=25600, num_positives=12800)
#   Threshold: 0.61328125
#   Precision: 0.9012702804678657
#   Recall:    0.55984375
#
# Body part: pelvis, Label: avascular_necrosis (num_samples=768, num_positives=384)
#   Threshold: 0.2265625
#   Precision: 0.9
#   Recall:    0.890625
#
# Body part: foot, Label: osteophytes (num_samples=5344, num_positives=2670)
#   Threshold: 0.70703125
#   Precision: 0.9007263922518159
#   Recall:    0.2786516853932584
#
# Body part: chest, Label: airspace_opacity (num_samples=36128, num_positives=18064)
#   Threshold: 0.59375
#   Precision: 0.9007168735065135
#   Recall:    0.6468666961913198
#
# Body part: c-spine, Label: intervertebral_disc_narrowing (num_samples=19232, num_positives=9617)
#   Threshold: 0.79296875
#   Precision: 0.9050179211469535
#   Recall:    0.15753353436622647
#
# Body part: arm, Label: soft_tissue_calcifications (num_samples=2656, num_positives=1330)
#   Threshold: 0.76171875
#   Precision: 0.9049128367670365
#   Recall:    0.4293233082706767
#
# Body part: foot, Label: soft_tissue_swelling (num_samples=22752, num_positives=11375)
#   Threshold: 0.55859375
#   Precision: 0.9008090045726346
#   Recall:    0.4502857142857143
#
# Body part: arm, Label: degenerative_changes (num_samples=16640, num_positives=8320)
#   Threshold: 0.71484375
#   Precision: 0.9020114942528735
#   Recall:    0.37728365384615387
#
# Body part: foot, Label: subchondral_cysts (num_samples=736, num_positives=367)
#   Threshold: 0.84765625
#   Precision: 0.9024390243902439
#   Recall:    0.1008174386920981
#
# Body part: t-spine, Label: compression_fracture (num_samples=1952, num_positives=971)
#   Threshold: 0.5
#   Precision: 0.9012738853503185
#   Recall:    0.5829042224510813
#
# Body part: abdomen, Label: stool (num_samples=23296, num_positives=11642)
#   Threshold: 0.609375
#   Precision: 0.9002493765586035
#   Recall:    0.43411784916680984
#
# Body part: l-spine, Label: spondylolisthesis (num_samples=20576, num_positives=10289)
#   Threshold: 0.55859375
#   Precision: 0.9008555611474585
#   Recall:    0.5219166099718145
#
# Body part: arm, Label: osteophytes (num_samples=5696, num_positives=2847)
#   Threshold: 0.68359375
#   Precision: 0.9023746701846965
#   Recall:    0.36037934668071653
#
# Body part: arm, Label: subcutaneous_gas (num_samples=448, num_positives=224)
#   Threshold: 0.09814453125
#   Precision: 0.9008264462809917
#   Recall:    0.9732142857142857
#
# Body part: abdomen, Label: degenerative_changes (num_samples=11936, num_positives=5977)
#   Threshold: 0.7265625
#   Precision: 0.900709219858156
#   Recall:    0.3399698845574703
#
# Body part: c-spine, Label: lordosis (num_samples=544, num_positives=271)
#   Threshold: 0.5390625
#   Precision: 0.92
#   Recall:    0.08487084870848709
#
# Body part: chest, Label: perihilar_opacity (num_samples=6368, num_positives=3182)
#   Threshold: 0.55859375
#   Precision: 0.9022026431718062
#   Recall:    0.6436203645505971
#
# Body part: c-spine, Label: postoperative_fusion_changes (num_samples=6272, num_positives=3135)
#   Threshold: 0.0191650390625
#   Precision: 0.9
#   Recall:    0.9961722488038277
#
# Body part: chest, Label: granuloma (num_samples=2112, num_positives=1056)
#   Threshold: 0.443359375
#   Precision: 0.9002463054187192
#   Recall:    0.6922348484848485
#
# Body part: head, Label: mucosal_thickening (num_samples=480, num_positives=238)
#   Threshold: 0.953125
#   Precision: 1.0
#   Recall:    0.012605042016806723
#
# Body part: foot, Label: arthritic_changes (num_samples=7392, num_positives=3695)
#   Threshold: 0.7421875
#   Precision: 0.9016722408026756
#   Recall:    0.3648173207036536
#
# Body part: leg, Label: joint_effusion (num_samples=16448, num_positives=8226)
#   Threshold: 0.6328125
#   Precision: 0.9002457002457003
#   Recall:    0.44541697058108437
#
# Body part: pelvis, Label: subcutaneous_gas (num_samples=1184, num_positives=592)
#   Threshold: 0.11767578125
#   Precision: 0.9004665629860031
#   Recall:    0.9780405405405406
#
# Body part: l-spine, Label: transitional_vertebrae (num_samples=3168, num_positives=1587)
#   Threshold: 0.63671875
#   Precision: 0.9024390243902439
#   Recall:    0.25645872715816004
#
# Body part: abdomen, Label: gallstones (num_samples=864, num_positives=431)
#   Threshold: 0.28125
#   Precision: 0.9008264462809917
#   Recall:    0.7587006960556845
#
# Body part: foot, Label: bony_mineralization (num_samples=2560, num_positives=1282)
#   Threshold: 0.5859375
#   Precision: 0.9016203703703703
#   Recall:    0.6076443057722309
#
# Body part: arm, Label: dislocation (num_samples=1568, num_positives=782)
#   Threshold: 0.2578125
#   Precision: 0.9002695417789758
#   Recall:    0.8542199488491049
#
# Body part: pelvis, Label: asymmetry (num_samples=672, num_positives=336)
#   Threshold: 0.408203125
#   Precision: 0.9036144578313253
#   Recall:    0.22321428571428573
#
# Body part: l-spine, Label: no_findings (num_samples=12992, num_positives=6496)
#   Threshold: 0.74609375
#   Precision: 0.9003350083752094
#   Recall:    0.4964593596059113
#
# Body part: arm, Label: joint_effusion (num_samples=2144, num_positives=1070)
#   Threshold: 0.44140625
#   Precision: 0.9010526315789473
#   Recall:    0.8
#
# Body part: leg, Label: osteophytes (num_samples=19776, num_positives=9889)
#   Threshold: 0.8125
#   Precision: 0.9001883239171374
#   Recall:    0.09667307108908889
#
# Body part: chest, Label: covid-19 (num_samples=1376, num_positives=687)
#   Threshold: 0.189453125
#   Precision: 0.9018492176386913
#   Recall:    0.9228529839883551
#
# Body part: chest, Label: sarcoidosis (num_samples=576, num_positives=287)
#   Threshold: 0.169921875
#   Precision: 0.9006849315068494
#   Recall:    0.9163763066202091
#
# Body part: foot, Label: nonunion (num_samples=576, num_positives=287)
#   Threshold: 0.53515625
#   Precision: 0.9011627906976745
#   Recall:    0.5400696864111498
#
# Body part: l-spine, Label: spinal_canal_narrowing (num_samples=512, num_positives=255)
#   Threshold: 0.88671875
#   Precision: 0.9166666666666666
#   Recall:    0.043137254901960784
#
# Body part: foot, Label: joint_space_narrowing (num_samples=3200, num_positives=1603)
#   Threshold: 0.66015625
#   Precision: 0.901307966706302
#   Recall:    0.4728633811603244
#
# Body part: chest, Label: pleural_effusion (num_samples=25600, num_positives=12798)
#   Threshold: 0.2080078125
#   Precision: 0.9003078727459317
#   Recall:    0.9596812001875293
#
# Body part: chest, Label: calcification (num_samples=41184, num_positives=20589)
#   Threshold: 0.671875
#   Precision: 0.901040778024228
#   Recall:    0.5129923745689445
#
# Body part: hand, Label: scaphoid_fracture (num_samples=608, num_positives=304)
#   Threshold: 0.53515625
#   Precision: 0.9
#   Recall:    0.47368421052631576
#
# Body part: leg, Label: calcifications (num_samples=1088, num_positives=542)
#   Threshold: 0.5234375
#   Precision: 0.9008498583569405
#   Recall:    0.5867158671586716
#
# Body part: l-spine, Label: degenerative_changes (num_samples=56544, num_positives=28272)
#   Threshold: 0.62890625
#   Precision: 0.9010036496350365
#   Recall:    0.628713921901528
#
# Body part: foot, Label: rarefaction (num_samples=3232, num_positives=1620)
#   Threshold: 0.66796875
#   Precision: 0.9020300088261254
#   Recall:    0.6308641975308642
#
# Body part: arm, Label: rarefaction (num_samples=704, num_positives=352)
#   Threshold: 0.703125
#   Precision: 0.9
#   Recall:    0.35795454545454547
#
# Body part: chest, Label: lung_volume_loss (num_samples=10560, num_positives=5283)
#   Threshold: 0.59765625
#   Precision: 0.9011536444677504
#   Recall:    0.6505773234904411
#
# Body part: chest, Label: post-surgical_changes (num_samples=21568, num_positives=10783)
#   Threshold: 0.330078125
#   Precision: 0.9001465738365702
#   Recall:    0.9112491885375128
#
# Body part: l-spine, Label: lordosis (num_samples=1408, num_positives=701)
#   Threshold: 0.8046875
#   Precision: 0.9117647058823529
#   Recall:    0.0442225392296719
#
# Body part: foot, Label: erosive_change (num_samples=1184, num_positives=591)
#   Threshold: 0.78125
#   Precision: 0.904
#   Recall:    0.3824027072758037
#
# Body part: l-spine, Label: lateral_curvature (num_samples=1216, num_positives=607)
#   Threshold: 0.8828125
#   Precision: 1.0
#   Recall:    0.008237232289950576
#
# Body part: chest, Label: asthma (num_samples=4736, num_positives=2369)
#   Threshold: 0.443359375
#   Precision: 0.9001046025104602
#   Recall:    0.7264668636555509
#
# Body part: chest, Label: support_devices (num_samples=54720, num_positives=27360)
#   Threshold: 0.45703125
#   Precision: 0.9001805123478127
#   Recall:    0.8566520467836257
#
# Body part: t-spine, Label: vertebral_height_loss (num_samples=1728, num_positives=861)
#   Threshold: 0.78515625
#   Precision: 0.9080459770114943
#   Recall:    0.1835075493612079
#
# Body part: hand, Label: growth_plate_abnormalities (num_samples=672, num_positives=335)
#   Threshold: 0.578125
#   Precision: 0.9032258064516129
#   Recall:    0.6686567164179105
#
# Body part: chest, Label: degenerative_changes (num_samples=56192, num_positives=28096)
#   Threshold: 0.6875
#   Precision: 0.9003582624272279
#   Recall:    0.28623291571753984
#
# Body part: arm, Label: acromioclavicular_joint_separation (num_samples=992, num_positives=496)
#   Threshold: 0.51953125
#   Precision: 0.9023569023569024
#   Recall:    0.5403225806451613
#
# Body part: hand, Label: joint_subluxation (num_samples=1536, num_positives=768)
#   Threshold: 0.54296875
#   Precision: 0.9006622516556292
#   Recall:    0.53125
#
# Body part: pelvis, Label: constipation (num_samples=1568, num_positives=783)
#   Threshold: 0.41796875
#   Precision: 0.9001447178002895
#   Recall:    0.7943805874840357
#
# Body part: arm, Label: rotator_cuff_calcific_tendinitis (num_samples=2528, num_positives=1266)
#   Threshold: 0.416015625
#   Precision: 0.9005059021922428
#   Recall:    0.8436018957345972
#
# Body part: abdomen, Label: foreign_bodies (num_samples=1728, num_positives=862)
#   Threshold: 0.33203125
#   Precision: 0.9001331557922769
#   Recall:    0.7842227378190255
#
# Body part: foot, Label: hammer_toe (num_samples=1152, num_positives=575)
#   Threshold: 0.60546875
#   Precision: 0.9006024096385542
#   Recall:    0.52
#
# Body part: l-spine, Label: spondylolysis (num_samples=2208, num_positives=1102)
#   Threshold: 0.3203125
#   Precision: 0.9003285870755751
#   Recall:    0.7459165154264973
#
# Body part: chest, Label: congestive_heart_failure (num_samples=3840, num_positives=1921)
#   Threshold: 0.34765625
#   Precision: 0.9002469135802469
#   Recall:    0.9489849036959916
#
# Body part: l-spine, Label: sacralization_of_l5 (num_samples=1472, num_positives=732)
#   Threshold: 0.7265625
#   Precision: 0.9016393442622951
#   Recall:    0.07513661202185792
#
# Body part: c-spine, Label: cervical_spine_alignment (num_samples=576, num_positives=289)
#   Threshold: 0.498046875
#   Precision: 0.6571428571428571
#   Recall:    0.07958477508650519
#
# Body part: c-spine, Label: spondylolisthesis (num_samples=5024, num_positives=2511)
#   Threshold: 0.71484375
#   Precision: 0.9018232819074333
#   Recall:    0.25607327757865395
#
# Body part: head, Label: sinusitis (num_samples=544, num_positives=270)
#   Threshold: 0.4765625
#   Precision: 0.9090909090909091
#   Recall:    0.2222222222222222
#
# Body part: chest, Label: hiatal_hernia (num_samples=3552, num_positives=1779)
#   Threshold: 0.0927734375
#   Precision: 0.9008822003113648
#   Recall:    0.9758291174817313
#
# Body part: chest, Label: flattening_of_the_hemi_diaphragm (num_samples=3968, num_positives=1987)
#   Threshold: 0.6953125
#   Precision: 0.9003407155025553
#   Recall:    0.5319577252138903
#
# Body part: t-spine, Label: bony_mineralization (num_samples=1792, num_positives=896)
#   Threshold: 0.63671875
#   Precision: 0.9055944055944056
#   Recall:    0.2890625
#
# Body part: leg, Label: bone_lesions (num_samples=2272, num_positives=1135)
#   Threshold: 0.455078125
#   Precision: 0.9013921113689095
#   Recall:    0.6845814977973568
#
# Body part: chest, Label: overlying_artifacts (num_samples=1376, num_positives=686)
#   Threshold: 0.46484375
#   Precision: 0.907258064516129
#   Recall:    0.32798833819241985
#
# Body part: abdomen, Label: renal_stones (num_samples=11776, num_positives=5884)
#   Threshold: 0.333984375
#   Precision: 0.9000879507475813
#   Recall:    0.8696464989802856
#
# Body part: t-spine, Label: postoperative_fusion_changes (num_samples=800, num_positives=399)
#   Threshold: 0.040283203125
#   Precision: 0.9016018306636155
#   Recall:    0.9874686716791979
#
# Body part: l-spine, Label: sacroiliitis (num_samples=704, num_positives=352)
#   Threshold: 0.97265625
#   Precision: 1.0
#   Recall:    0.002840909090909091
#
# Body part: pelvis, Label: sacralization_of_spine (num_samples=736, num_positives=368)
#   Threshold: 0.3984375
#   Precision: 0.9041916167664671
#   Recall:    0.41032608695652173
#
# Body part: pelvis, Label: iud (num_samples=1216, num_positives=608)
#   Threshold: 0.018798828125
#   Precision: 0.900593471810089
#   Recall:    0.9983552631578947
#
# Body part: l-spine, Label: vacuum_disc_phenomenon (num_samples=1440, num_positives=720)
#   Threshold: 0.5390625
#   Precision: 0.9001919385796545
#   Recall:    0.6513888888888889
#
# Body part: abdomen, Label: bowel_obstruction (num_samples=4960, num_positives=2480)
#   Threshold: 0.4765625
#   Precision: 0.9002197802197802
#   Recall:    0.8258064516129032
#
# Body part: arm, Label: enthesophytes (num_samples=1664, num_positives=831)
#   Threshold: 0.470703125
#   Precision: 0.9001560062402496
#   Recall:    0.694344163658243
#
# Body part: leg, Label: foreign_bodies (num_samples=832, num_positives=415)
#   Threshold: 0.267578125
#   Precision: 0.9010152284263959
#   Recall:    0.8554216867469879
#
# Body part: abdomen, Label: air_fluid_levels (num_samples=3296, num_positives=1651)
#   Threshold: 0.44140625
#   Precision: 0.9009646302250803
#   Recall:    0.8485766202301636
#
# Body part: leg, Label: meniscal_calcifications (num_samples=1856, num_positives=924)
#   Threshold: 0.310546875
#   Precision: 0.9
#   Recall:    0.8474025974025974
#
# Body part: foot, Label: joint_subluxation (num_samples=1056, num_positives=527)
#   Threshold: 0.64453125
#   Precision: 0.9
#   Recall:    0.4952561669829222
#
# Body part: chest, Label: atelectasis (num_samples=40864, num_positives=20430)
#   Threshold: 0.65234375
#   Precision: 0.9008734674252744
#   Recall:    0.5502692119432208
#
# Body part: hand, Label: buckle_fracture (num_samples=896, num_positives=446)
#   Threshold: 0.28125
#   Precision: 0.9012875536480687
#   Recall:    0.9417040358744395
#
# Body part: arm, Label: joint_space_narrowing (num_samples=3168, num_positives=1584)
#   Threshold: 0.60546875
#   Precision: 0.9050218340611353
#   Recall:    0.5233585858585859
#
# Body part: chest, Label: mediastinal_shift (num_samples=512, num_positives=255)
#   Threshold: 0.08642578125
#   Precision: 0.9021739130434783
#   Recall:    0.9764705882352941
#
# Body part: leg, Label: no_findings (num_samples=24064, num_positives=12031)
#   Threshold: 0.66015625
#   Precision: 0.9006829494154416
#   Recall:    0.6467459064084449
#
# Body part: foot, Label: fracture (num_samples=19264, num_positives=9634)
#   Threshold: 0.447265625
#   Precision: 0.9006075712727839
#   Recall:    0.6000622794270293
#
# Body part: abdomen, Label: support_devices (num_samples=23808, num_positives=11903)
#   Threshold: 0.302734375
#   Precision: 0.9002841858910063
#   Recall:    0.9048979248928841
#
# Body part: chest, Label: enlarged_mediastinum (num_samples=992, num_positives=496)
#   Threshold: 0.451171875
#   Precision: 0.901060070671378
#   Recall:    0.5141129032258065
#
# Body part: hand, Label: degenerative_changes (num_samples=13152, num_positives=6578)
#   Threshold: 0.7265625
#   Precision: 0.9002898550724637
#   Recall:    0.47217999391912435
#
# Body part: foot, Label: osteomyelitis (num_samples=1152, num_positives=574)
#   Threshold: 0.5078125
#   Precision: 0.9013539651837524
#   Recall:    0.8118466898954704
#
# Body part: abdomen, Label: surgical_clips_or_staples (num_samples=9952, num_positives=4977)
#   Threshold: 0.5625
#   Precision: 0.9004798664719382
#   Recall:    0.8671890697207153
#
# Body part: chest, Label: osteoporosis (num_samples=8032, num_positives=4016)
#   Threshold: 0.7421875
#   Precision: 0.9016751638747269
#   Recall:    0.30826693227091634
#
# Body part: foot, Label: accessory_ossicles (num_samples=2880, num_positives=1442)
#   Threshold: 0.78125
#   Precision: 0.9047619047619048
#   Recall:    0.07905686546463246
#
# Body part: l-spine, Label: pars_interarticularis_defects (num_samples=928, num_positives=464)
#   Threshold: 0.4765625
#   Precision: 0.9010238907849829
#   Recall:    0.5689655172413793
#
# Body part: leg, Label: support_devices (num_samples=14048, num_positives=7024)
#   Threshold: 0.049560546875
#   Precision: 0.9009304154108243
#   Recall:    0.9787870159453302
#
# Body part: l-spine, Label: spondylosis (num_samples=8512, num_positives=4256)
#   Threshold: 0.8046875
#   Precision: 0.9
#   Recall:    0.03806390977443609
#
# Body part: t-spine, Label: degenerative_changes (num_samples=9504, num_positives=4752)
#   Threshold: 0.56640625
#   Precision: 0.9002822201317028
#   Recall:    0.6041666666666666
#
# Body part: hand, Label: bone_lesions (num_samples=1440, num_positives=719)
#   Threshold: 0.6484375
#   Precision: 0.9011627906976745
#   Recall:    0.21557719054242003
#
# Body part: arm, Label: tendinous_calcifications (num_samples=1440, num_positives=718)
#   Threshold: 0.59375
#   Precision: 0.900990099009901
#   Recall:    0.5069637883008357
#
# Body part: hand, Label: ossicles (num_samples=1120, num_positives=560)
#   Threshold: 0.69921875
#   Precision: 0.9015748031496063
#   Recall:    0.4089285714285714
#
# Body part: t-spine, Label: intervertebral_disc_narrowing (num_samples=2240, num_positives=1120)
#   Threshold: 0.734375
#   Precision: 0.9076923076923077
#   Recall:    0.26339285714285715
#
# Body part: pelvis, Label: arthritis (num_samples=9728, num_positives=4864)
#   Threshold: 0.6640625
#   Precision: 0.9013303769401331
#   Recall:    0.5014391447368421
#
# Body part: chest, Label: subcutaneous_emphysema (num_samples=544, num_positives=270)
#   Threshold: 0.054931640625
#   Precision: 0.9020979020979021
#   Recall:    0.9555555555555556
#
# Body part: c-spine, Label: neural_foraminal_narrowing (num_samples=7008, num_positives=3503)
#   Threshold: 0.74609375
#   Precision: 0.9003322259136213
#   Recall:    0.696260348272909
#
# Body part: chest, Label: pulmonary_edema (num_samples=8032, num_positives=4015)
#   Threshold: 0.369140625
#   Precision: 0.9000246244767298
#   Recall:    0.9103362391033624
#
# Body part: arm, Label: support_devices (num_samples=5568, num_positives=2782)
#   Threshold: 0.1259765625
#   Precision: 0.9001026342798495
#   Recall:    0.9457225017972681
#
# Body part: chest, Label: tracheal_deviation (num_samples=768, num_positives=383)
#   Threshold: 0.388671875
#   Precision: 0.9009433962264151
#   Recall:    0.49869451697127937
#
# Body part: t-spine, Label: support_devices (num_samples=2368, num_positives=1186)
#   Threshold: 0.328125
#   Precision: 0.9015151515151515
#   Recall:    0.903035413153457
#
# Body part: foot, Label: support_devices (num_samples=6336, num_positives=3167)
#   Threshold: 0.061767578125
#   Precision: 0.9011695906432748
#   Recall:    0.9731607199242185
#
# Body part: pelvis, Label: degenerative_changes (num_samples=25440, num_positives=12717)
#   Threshold: 0.625
#   Precision: 0.9017168885774351
#   Recall:    0.404733820869702
#
# Body part: head, Label: support_devices (num_samples=480, num_positives=239)
#   Threshold: 0.203125
#   Precision: 0.9020618556701031
#   Recall:    0.7322175732217573
#
# Body part: chest, Label: diaphragmatic_eventration (num_samples=1760, num_positives=877)
#   Threshold: 0.396484375
#   Precision: 0.9008264462809917
#   Recall:    0.7457240592930444
#
# Body part: t-spine, Label: spondylosis (num_samples=1504, num_positives=752)
#   Threshold: 0.91796875
#   Precision: 0.9166666666666666
#   Recall:    0.014627659574468085
#
# Body part: hand, Label: soft_tissue_swelling (num_samples=11648, num_positives=5824)
#   Threshold: 0.671875
#   Precision: 0.9003367003367003
#   Recall:    0.22956730769230768
#
# Body part: c-spine, Label: osteophytes (num_samples=18784, num_positives=9394)
#   Threshold: 0.80859375
#   Precision: 0.9035812672176309
#   Recall:    0.03491590376836279
#
# Body part: chest, Label: foreign_bodies (num_samples=1088, num_positives=544)
#   Threshold: 0.1279296875
#   Precision: 0.9011194029850746
#   Recall:    0.8878676470588235
#
# Body part: l-spine, Label: osteophytes (num_samples=30176, num_positives=15088)
#   Threshold: 0.7578125
#   Precision: 0.9009009009009009
#   Recall:    0.12592788971367974
#
# Body part: chest, Label: bronchiectasis (num_samples=864, num_positives=432)
#   Threshold: 0.369140625
#   Precision: 0.9008746355685131
#   Recall:    0.7152777777777778
#
# Body part: chest, Label: interstitial_lung_disease_(ild) (num_samples=14624, num_positives=7313)
#   Threshold: 0.64453125
#   Precision: 0.9007924860581157
#   Recall:    0.4196636127444277
#
# Body part: leg, Label: enthesophytes (num_samples=4288, num_positives=2145)
#   Threshold: 0.70703125
#   Precision: 0.9
#   Recall:    0.4405594405594406
#
# Body part: t-spine, Label: aortic_calcifications (num_samples=448, num_positives=224)
#   Threshold: 0.9765625
#   Precision: 1.0
#   Recall:    0.008928571428571428
#
# Body part: foot, Label: subcutaneous_gas (num_samples=608, num_positives=304)
#   Threshold: 0.31640625
#   Precision: 0.9
#   Recall:    0.8881578947368421
#
# Body part: abdomen, Label: constipation (num_samples=5728, num_positives=2863)
#   Threshold: 0.7578125
#   Precision: 0.9015873015873016
#   Recall:    0.29758994062172545
#
# Body part: chest, Label: consolidation (num_samples=6848, num_positives=3424)
#   Threshold: 0.56640625
#   Precision: 0.9004402302742973
#   Recall:    0.7765771028037384
#
# Body part: c-spine, Label: calcifications (num_samples=1088, num_positives=543)
#   Threshold: 0.70703125
#   Precision: 0.9036144578313253
#   Recall:    0.13812154696132597
#
# Body part: t-spine, Label: no_findings (num_samples=5344, num_positives=2670)
#   Threshold: 0.71484375
#   Precision: 0.9017735334242838
#   Recall:    0.4951310861423221
#
# Body part: hand, Label: rarefaction (num_samples=1984, num_positives=987)
#   Threshold: 0.69921875
#   Precision: 0.900952380952381
#   Recall:    0.47922998986828774
#
# Body part: chest, Label: emphysema (num_samples=11008, num_positives=5505)
#   Threshold: 0.59375
#   Precision: 0.900739984689972
#   Recall:    0.6412352406902816
#
# Body part: arm, Label: ossicles (num_samples=800, num_positives=400)
#   Threshold: 0.6796875
#   Precision: 0.900709219858156
#   Recall:    0.3175
#
# Body part: leg, Label: fracture (num_samples=9632, num_positives=4817)
#   Threshold: 0.298828125
#   Precision: 0.9001153402537485
#   Recall:    0.8100477475607224
#
# Body part: foot, Label: dislocation (num_samples=864, num_positives=431)
#   Threshold: 0.310546875
#   Precision: 0.9014423076923077
#   Recall:    0.8700696055684455
#
# Body part: foot, Label: enthesophytes (num_samples=24736, num_positives=12368)
#   Threshold: 0.578125
#   Precision: 0.9007928440739987
#   Recall:    0.7165265200517464
#
# Body part: hand, Label: dislocation (num_samples=576, num_positives=288)
#   Threshold: 0.4375
#   Precision: 0.9
#   Recall:    0.71875
#
# Body part: chest, Label: hyperinflation (num_samples=31328, num_positives=15663)
#   Threshold: 0.67578125
#   Precision: 0.9005611672278339
#   Recall:    0.5122901104513823
#
# Body part: c-spine, Label: carotid_calcifications (num_samples=1536, num_positives=766)
#   Threshold: 0.359375
#   Precision: 0.9001280409731114
#   Recall:    0.9177545691906005
#
# Body part: foot, Label: hallux_valgus (num_samples=5280, num_positives=2638)
#   Threshold: 0.404296875
#   Precision: 0.9000822368421053
#   Recall:    0.8297952994692949
#
# Body part: arm, Label: joint_subluxation (num_samples=704, num_positives=352)
#   Threshold: 0.65234375
#   Precision: 0.9112903225806451
#   Recall:    0.3210227272727273
#
# Body part: c-spine, Label: listhesis (num_samples=2816, num_positives=1410)
#   Threshold: 0.69921875
#   Precision: 1.0
#   Recall:    0.0007092198581560284
#
# Body part: hand, Label: amputation (num_samples=480, num_positives=240)
#   Threshold: 0.2158203125
#   Precision: 0.9017857142857143
#   Recall:    0.8416666666666667
#
# Body part: chest, Label: no_findings (num_samples=105696, num_positives=52846)
#   Threshold: 0.65625
#   Precision: 0.9002180364605414
#   Recall:    0.5625212882715815
#
# Body part: t-spine, Label: kyphosis (num_samples=1344, num_positives=671)
#   Threshold: 0.498046875
#   Precision: 0.9
#   Recall:    0.5230998509687034
#
# Body part: hand, Label: support_devices (num_samples=3936, num_positives=1971)
#   Threshold: 0.12109375
#   Precision: 0.9013882240306367
#   Recall:    0.9553526128868595
#
# Body part: hand, Label: arthritic_changes (num_samples=12800, num_positives=6402)
#   Threshold: 0.609375
#   Precision: 0.900982160753658
#   Recall:    0.7021243361449547
#
# Body part: arm, Label: soft_tissue_swelling (num_samples=3904, num_positives=1955)
#   Threshold: 0.62890625
#   Precision: 0.9007036747458952
#   Recall:    0.5892583120204603
#
# Body part: chest, Label: fibrosis (num_samples=6912, num_positives=3456)
#   Threshold: 0.578125
#   Precision: 0.9007874015748032
#   Recall:    0.6620370370370371
#
# Body part: chest, Label: scoliosis (num_samples=15776, num_positives=7891)
#   Threshold: 0.5234375
#   Precision: 0.9004510810390418
#   Recall:    0.7336205804080598
#
# Body part: leg, Label: joint_space_narrowing (num_samples=22944, num_positives=11471)
#   Threshold: 0.6171875
#   Precision: 0.9010261072866607
#   Recall:    0.6047423938627844
#
# Body part: pelvis, Label: subchondral_cyst (num_samples=1376, num_positives=688)
#   Threshold: 0.390625
#   Precision: 0.9
#   Recall:    0.7194767441860465
#
# Body part: l-spine, Label: schmorl's_node (num_samples=704, num_positives=351)
#   Threshold: 0.5
#   Precision: 0.7297297297297297
#   Recall:    0.07692307692307693
#
# Body part: abdomen, Label: abnormal_calcifications (num_samples=7136, num_positives=3568)
#   Threshold: 0.73046875
#   Precision: 0.9036334913112164
#   Recall:    0.16031390134529147
#
# Body part: pelvis, Label: fracture (num_samples=8000, num_positives=4000)
#   Threshold: 0.3984375
#   Precision: 0.9001088731627653
#   Recall:    0.82675
#
# Body part: pelvis, Label: bony_mineralization (num_samples=7680, num_positives=3839)
#   Threshold: 0.7109375
#   Precision: 0.9004804392587509
#   Recall:    0.3417556655379005
#
# Body part: c-spine, Label: uncovertebral_joint_arthrosis (num_samples=2592, num_positives=1298)
#   Threshold: 0.8046875
#   Precision: 0.9183673469387755
#   Recall:    0.03466872110939907
#
# Body part: pelvis, Label: stool (num_samples=7680, num_positives=3840)
#   Threshold: 0.5703125
#   Precision: 0.9004605030109812
#   Recall:    0.6619791666666667
#
# Body part: c-spine, Label: kyphosis (num_samples=640, num_positives=319)
#   Threshold: 0.498046875
#   Precision: 0.9014084507042254
#   Recall:    0.4012539184952978
#
# Body part: leg, Label: intra-articular_bodies (num_samples=2272, num_positives=1136)
#   Threshold: 0.5703125
#   Precision: 0.9
#   Recall:    0.6496478873239436
#
# Body part: hand, Label: foreign_bodies (num_samples=1440, num_positives=720)
#   Threshold: 0.41015625
#   Precision: 0.900990099009901
#   Recall:    0.7583333333333333
#
# Body part: l-spine, Label: bony_mineralization (num_samples=5888, num_positives=2943)
#   Threshold: 0.68359375
#   Precision: 0.9007506255212677
#   Recall:    0.3669724770642202
#
# Body part: chest, Label: pleural_plaque (num_samples=768, num_positives=383)
#   Threshold: 0.1484375
#   Precision: 0.9
#   Recall:    0.9164490861618799
#
# Body part: c-spine, Label: bony_mineralization (num_samples=2176, num_positives=1090)
#   Threshold: 0.455078125
#   Precision: 0.901010101010101
#   Recall:    0.4091743119266055
#
# Body part: foot, Label: degenerative_changes (num_samples=13440, num_positives=6722)
#   Threshold: 0.73828125
#   Precision: 0.9029075804776739
#   Recall:    0.25870276703362094
#
# Body part: pelvis, Label: pelvic_vascular_calcifications (num_samples=5856, num_positives=2926)
#   Threshold: 0.55078125
#   Precision: 0.9
#   Recall:    0.7289815447710185
#
# Body part: leg, Label: tendinous_calcifications (num_samples=512, num_positives=255)
#   Threshold: 0.5390625
#   Precision: 0.905982905982906
#   Recall:    0.41568627450980394
#
# Body part: pelvis, Label: pelvic_tilt (num_samples=960, num_positives=479)
#   Threshold: 0.1201171875
#   Precision: 0.9016736401673641
#   Recall:    0.8997912317327766
#
# Body part: foot, Label: os_trigonum (num_samples=704, num_positives=352)
#   Threshold: 0.423828125
#   Precision: 0.9
#   Recall:    0.5625
#
# Body part: hand, Label: bony_mineralization (num_samples=2656, num_positives=1331)
#   Threshold: 0.75390625
#   Precision: 0.9020134228187919
#   Recall:    0.5048835462058603
#
# Body part: leg, Label: degenerative_changes (num_samples=26592, num_positives=13295)
#   Threshold: 0.75
#   Precision: 0.9002274019329164
#   Recall:    0.23820985332831893
#
# Body part: chest, Label: bronchitis (num_samples=18368, num_positives=9185)
#   Threshold: 0.73828125
#   Precision: 0.9027093596059114
#   Recall:    0.23941208492106697
#
# Body part: hand, Label: fracture (num_samples=18112, num_positives=9057)
#   Threshold: 0.4296875
#   Precision: 0.9004269384382316
#   Recall:    0.7218725847410843
#
# Body part: leg, Label: soft_tissue_swelling (num_samples=5728, num_positives=2861)
#   Threshold: 0.6484375
#   Precision: 0.9039451114922813
#   Recall:    0.3684026564138413
#
# Body part: leg, Label: subcutaneous_gas (num_samples=1568, num_positives=780)
#   Threshold: 0.1455078125
#   Precision: 0.9011904761904762
#   Recall:    0.9705128205128205
#
# Body part: head, Label: no_findings (num_samples=6176, num_positives=3086)
#   Threshold: 0.671875
#   Precision: 0.9026128266033254
#   Recall:    0.12313674659753726
#
# Body part: foot, Label: bone_lesions (num_samples=1088, num_positives=544)
#   Threshold: 0.462890625
#   Precision: 0.9004739336492891
#   Recall:    0.3492647058823529
#
# Body part: hand, Label: joint_space_narrowing (num_samples=5376, num_positives=2687)
#   Threshold: 0.73046875
#   Precision: 0.9018624641833811
#   Recall:    0.4685522887979159
#
# Body part: chest, Label: pleural_thickening (num_samples=8576, num_positives=4289)
#   Threshold: 0.62109375
#   Precision: 0.9004774146162321
#   Recall:    0.5716950338074143
#
# Body part: chest, Label: cardiomegaly (num_samples=47072, num_positives=23535)
#   Threshold: 0.470703125
#   Precision: 0.9000089678055779
#   Recall:    0.8528574463564903
#
# Body part: leg, Label: patellar_tracking_abnormalities (num_samples=1024, num_positives=511)
#   Threshold: 0.62890625
#   Precision: 0.9
#   Recall:    0.299412915851272
#
# Body part: arm, Label: bony_mineralization (num_samples=3040, num_positives=1521)
#   Threshold: 0.7578125
#   Precision: 0.9074074074074074
#   Recall:    0.2255095332018409
#
# Body part: chest, Label: mass_nodule (num_samples=15328, num_positives=7666)
#   Threshold: 0.62890625
#   Precision: 0.9006474103585658
#   Recall:    0.4718236368379859
#
# Body part: foot, Label: edema (num_samples=1120, num_positives=559)
#   Threshold: 0.6953125
#   Precision: 0.9020979020979021
#   Recall:    0.23076923076923078
#
# Body part: leg, Label: rarefaction (num_samples=2432, num_positives=1218)
#   Threshold: 0.671875
#   Precision: 0.9020979020979021
#   Recall:    0.4236453201970443
#
# Body part: pelvis, Label: no_findings (num_samples=28128, num_positives=14063)
#   Threshold: 0.6875
#   Precision: 0.9011659192825112
#   Recall:    0.35724952001706606
#
# Body part: c-spine, Label: spondylosis (num_samples=6976, num_positives=3487)
#   Threshold: 0.765625
#   Precision: 0.9009009009009009
#   Recall:    0.05735589331803843
#
# Body part: chest, Label: calcified_granuloma (num_samples=5728, num_positives=2863)
#   Threshold: 0.328125
#   Precision: 0.9004629629629629
#   Recall:    0.8152287809989521
#
# Body part: leg, Label: joint_subluxation (num_samples=864, num_positives=431)
#   Threshold: 0.515625
#   Precision: 0.9009433962264151
#   Recall:    0.4431554524361949
#
# Body part: pelvis, Label: urologic_stent (num_samples=960, num_positives=480)
#   Threshold: 0.0194091796875
#   Precision: 0.9034090909090909
#   Recall:    0.99375
#
# Body part: pelvis, Label: enthesopathy (num_samples=992, num_positives=495)
#   Threshold: 0.41796875
#   Precision: 0.9011406844106464
#   Recall:    0.47878787878787876
#
# Body part: pelvis, Label: bone_lesions (num_samples=1984, num_positives=987)
#   Threshold: 0.62109375
#   Precision: 0.9011627906976745
#   Recall:    0.47112462006079026
#
# Body part: foot, Label: ossicles (num_samples=960, num_positives=481)
#   Threshold: 0.8203125
#   Precision: 0.9080459770114943
#   Recall:    0.16424116424116425
#
# Body part: t-spine, Label: detroconvex (num_samples=4288, num_positives=2146)
#   Threshold: 0.78125
#   Precision: 0.9070904645476773
#   Recall:    0.17287977632805218
#
# Body part: head, Label: fracture (num_samples=736, num_positives=368)
#   Threshold: 0.57421875
#   Precision: 0.9
#   Recall:    0.4157608695652174
#
# Body part: pelvis, Label: support_devices (num_samples=22208, num_positives=11102)
#   Threshold: 0.3203125
#   Precision: 0.9003693281744636
#   Recall:    0.9222662583318321
#
# Body part: t-spine, Label: osteophytes (num_samples=4736, num_positives=2366)
#   Threshold: 0.7734375
#   Precision: 0.900990099009901
#   Recall:    0.038461538461538464
#
# Body part: foot, Label: no_findings (num_samples=24448, num_positives=12224)
#   Threshold: 0.7421875
#   Precision: 0.9020048392671967
#   Recall:    0.4269469895287958
#
# Body part: foot, Label: joint_effusion (num_samples=1568, num_positives=781)
#   Threshold: 0.60546875
#   Precision: 0.9013761467889908
#   Recall:    0.5032010243277849
#
# Body part: chest, Label: venous_congestion (num_samples=9856, num_positives=4928)
#   Threshold: 0.478515625
#   Precision: 0.9005719313682358
#   Recall:    0.830762987012987
#
# Body part: chest, Label: pacemaker_leads (num_samples=6304, num_positives=3150)
#   Threshold: 0.01031494140625
#   Precision: 0.9014367816091954
#   Recall:    0.9958730158730159
#
# Body part: pelvis, Label: femoral_acetabular_impingement (num_samples=416, num_positives=208)
#   Threshold: 0.59375
#   Precision: 0.9
#   Recall:    0.34615384615384615
#
# Body part: foot, Label: periosteal_reaction (num_samples=480, num_positives=240)
#   Threshold: 0.73046875
#   Precision: 0.9076923076923077
#   Recall:    0.24583333333333332
#
# Body part: hand, Label: no_findings (num_samples=30336, num_positives=15168)
#   Threshold: 0.6484375
#   Precision: 0.901958614584486
#   Recall:    0.537381329113924
#
# Body part: chest, Label: pneumonia (num_samples=22240, num_positives=11120)
#   Threshold: 0.57421875
#   Precision: 0.9002153625269204
#   Recall:    0.6766187050359712
#
# Body part: c-spine, Label: scoliosis (num_samples=1344, num_positives=671)
#   Threshold: 0.87890625
#   Precision: 0.9393939393939394
#   Recall:    0.046199701937406856
#
# Body part: abdomen, Label: ureteral_stents (num_samples=2208, num_positives=1105)
#   Threshold: 0.015869140625
#   Precision: 0.9014778325123153
#   Recall:    0.9936651583710407
#
# Body part: arm, Label: fat_pad_signs_suggesting_joint_effusion (num_samples=512, num_positives=255)
#   Threshold: 0.486328125
#   Precision: 0.9013452914798207
#   Recall:    0.788235294117647
#
# Body part: leg, Label: soft_tissue_calcifications (num_samples=8608, num_positives=4305)
#   Threshold: 0.55078125
#   Precision: 0.9000566251415628
#   Recall:    0.7384436701509872
#
# Body part: abdomen, Label: calcified_phleboliths (num_samples=9920, num_positives=4961)
#   Threshold: 0.7265625
#   Precision: 0.9011177987962167
#   Recall:    0.42249546462406773
#
# Body part: c-spine, Label: support_devices (num_samples=6880, num_positives=3439)
#   Threshold: 0.09130859375
#   Precision: 0.9003789929615593
#   Recall:    0.9671416109334109
#
# Body part: l-spine, Label: facet_joint_arthropathy (num_samples=31616, num_positives=15808)
#   Threshold: 0.77734375
#   Precision: 0.9003021148036254
#   Recall:    0.1508097165991903

# %%
import csv
import sys

# Prepare CSV header
csv_header = ["body_part", "label", "r@90%p", "threshold@90%p"]

# Print CSV header
print(",".join(csv_header))

# Iterate through threshold_info to extract required fields
for t in threshold_info:
    body_part = t.get("body_part", "")
    label = t.get("label", "")
    recall_at_90p = ""
    threshold_at_90p = ""
    # Try to get recall and threshold at 90% precision
    if "precision" in t and "recall" in t and "threshold" in t:
        precision = t["precision"]
        recall = t["recall"]
        threshold = t["threshold"]
        # If this threshold is at least 90% precision, use its recall and threshold
        if precision is not None and recall is not None and threshold is not None and precision >= 0.9:
            recall_at_90p = f"{recall:.4f}"
            threshold_at_90p = f"{threshold:.4f}"
        else:
            recall_at_90p = ""
            threshold_at_90p = ""
    print(f"{body_part},{label},{recall_at_90p},{threshold_at_90p}")
# Out:
# body_part,label,r@90%p,threshold@90%p
# arm,fracture,0.7907,0.3496
# hand,tendon_avulsion_fractures,0.2562,0.6680
# l-spine,support_devices,0.8806,0.3848
# abdomen,no_findings,0.3496,0.7070
# hand,ulnar_variance,0.0055,0.8945
# chest,enlarged_pulmonary_artery,0.6782,0.4531
# abdomen,iud,0.9884,0.0272
# abdomen,bowel_dilation,0.8182,0.4512
# l-spine,spina_bifida_occulta,0.1287,0.5625
# t-spine,scoliosis,0.5792,0.5312
# hand,osteophytes,0.4241,0.7266
# chest,aortic_elongation_enlargement,0.7066,0.6016
# leg,heterotopic_ossification,0.4797,0.6094
# leg,arthritic_changes,0.2718,0.7383
# arm,foreign_bodies,0.7853,0.3984
# t-spine,levoconvex,0.3619,0.6523
# leg,edema,0.3879,0.6133
# foot,synostosis,0.4583,0.4688
# c-spine,degenerative_changes,0.6826,0.6289
# chest,fracture,0.6402,0.5195
# abdomen,uterine_fibroids,0.8845,0.0942
# abdomen,ileus,0.5666,0.6641
# chest,pneumonitis,0.5008,0.6602
# foot,soft_tissue_calcifications,0.7266,0.4219
# leg,bony_mineralization,0.1942,0.7461
# c-spine,no_findings,0.7480,0.5938
# l-spine,vertebral_height_loss,0.4119,0.6562
# foot,tendinous_calcifications,0.5470,0.5195
# hand,erosive_change,0.5292,0.5391
# pelvis,heterotopic_ossification,0.7455,0.2812
# foot,foreign_bodies,0.6162,0.4043
# l-spine,postoperative_fusion_changes,0.9930,0.0194
# chest,adenopathy,0.6888,0.3828
# arm,arthritic_changes,0.3304,0.7227
# chest,cardiac_devices,0.9866,0.0674
# chest,pneumothorax,0.9104,0.2754
# l-spine,fracture,0.0072,0.9844
# pelvis,dislocation,0.8747,0.2041
# arm,bone_lesions,0.3894,0.5312
# foot,os_navicularis,0.5323,0.4355
# abdomen,ureteral_calculi,0.6094,0.6289
# c-spine,facet_joint_hypertrophy_or_arthropathy,0.3414,0.7188
# foot,amputation,0.9427,0.1494
# pelvis,cam_deformity,0.6347,0.4082
# chest,scarring,0.4729,0.6836
# leg,ossicles,0.3792,0.5938
# pelvis,soft_tissue_calcifications,0.5504,0.5430
# chest,arthritis,0.7299,0.3242
# abdomen,colonic_distension,0.7193,0.5234
# pelvis,soft_tissue_swelling,0.1211,0.8281
# hand,soft_tissue_calcifications,0.6784,0.5000
# l-spine,scoliosis,0.6430,0.5430
# abdomen,free_air,0.3013,0.5312
# l-spine,straightening,0.4656,0.7070
# l-spine,intervertebral_disc_narrowing,0.2998,0.7227
# c-spine,hardware,0.9969,0.3086
# hand,nonunion,0.7398,0.3086
# pelvis,ureteral_calculi,0.9071,0.5586
# chest,costophrenic_angle_blunting,0.7602,0.5820
# chest,tortuous_aorta,0.4577,0.7266
# leg,subchondral_cyst,0.3618,0.4180
# arm,no_findings,0.4485,0.6719
# chest,diaphragmatic_elevation,0.8908,0.3945
# chest,hernia,0.9269,0.1602
# pelvis,pelvic_phleboliths,0.5783,0.6055
# abdomen,abnormal_gas_patterns,0.0953,0.7617
# l-spine,lumbarization_of_s1,0.0019,0.9141
# l-spine,aortic_calcifications,0.6514,0.7109
# c-spine,straightening,0.5598,0.6133
# pelvis,avascular_necrosis,0.8906,0.2266
# foot,osteophytes,0.2787,0.7070
# chest,airspace_opacity,0.6469,0.5938
# c-spine,intervertebral_disc_narrowing,0.1575,0.7930
# arm,soft_tissue_calcifications,0.4293,0.7617
# foot,soft_tissue_swelling,0.4503,0.5586
# arm,degenerative_changes,0.3773,0.7148
# foot,subchondral_cysts,0.1008,0.8477
# t-spine,compression_fracture,0.5829,0.5000
# abdomen,stool,0.4341,0.6094
# l-spine,spondylolisthesis,0.5219,0.5586
# arm,osteophytes,0.3604,0.6836
# arm,subcutaneous_gas,0.9732,0.0981
# abdomen,degenerative_changes,0.3400,0.7266
# c-spine,lordosis,0.0849,0.5391
# chest,perihilar_opacity,0.6436,0.5586
# c-spine,postoperative_fusion_changes,0.9962,0.0192
# chest,granuloma,0.6922,0.4434
# head,mucosal_thickening,0.0126,0.9531
# foot,arthritic_changes,0.3648,0.7422
# leg,joint_effusion,0.4454,0.6328
# pelvis,subcutaneous_gas,0.9780,0.1177
# l-spine,transitional_vertebrae,0.2565,0.6367
# abdomen,gallstones,0.7587,0.2812
# foot,bony_mineralization,0.6076,0.5859
# arm,dislocation,0.8542,0.2578
# pelvis,asymmetry,0.2232,0.4082
# l-spine,no_findings,0.4965,0.7461
# arm,joint_effusion,0.8000,0.4414
# leg,osteophytes,0.0967,0.8125
# chest,covid-19,0.9229,0.1895
# chest,sarcoidosis,0.9164,0.1699
# foot,nonunion,0.5401,0.5352
# l-spine,spinal_canal_narrowing,0.0431,0.8867
# foot,joint_space_narrowing,0.4729,0.6602
# chest,pleural_effusion,0.9597,0.2080
# chest,calcification,0.5130,0.6719
# hand,scaphoid_fracture,0.4737,0.5352
# leg,calcifications,0.5867,0.5234
# l-spine,degenerative_changes,0.6287,0.6289
# foot,rarefaction,0.6309,0.6680
# arm,rarefaction,0.3580,0.7031
# chest,lung_volume_loss,0.6506,0.5977
# chest,post-surgical_changes,0.9112,0.3301
# l-spine,lordosis,0.0442,0.8047
# foot,erosive_change,0.3824,0.7812
# l-spine,lateral_curvature,0.0082,0.8828
# chest,asthma,0.7265,0.4434
# chest,support_devices,0.8567,0.4570
# t-spine,vertebral_height_loss,0.1835,0.7852
# hand,growth_plate_abnormalities,0.6687,0.5781
# chest,degenerative_changes,0.2862,0.6875
# arm,acromioclavicular_joint_separation,0.5403,0.5195
# hand,joint_subluxation,0.5312,0.5430
# pelvis,constipation,0.7944,0.4180
# arm,rotator_cuff_calcific_tendinitis,0.8436,0.4160
# abdomen,foreign_bodies,0.7842,0.3320
# foot,hammer_toe,0.5200,0.6055
# l-spine,spondylolysis,0.7459,0.3203
# chest,congestive_heart_failure,0.9490,0.3477
# l-spine,sacralization_of_l5,0.0751,0.7266
# c-spine,cervical_spine_alignment,,
# c-spine,spondylolisthesis,0.2561,0.7148
# head,sinusitis,0.2222,0.4766
# chest,hiatal_hernia,0.9758,0.0928
# chest,flattening_of_the_hemi_diaphragm,0.5320,0.6953
# t-spine,bony_mineralization,0.2891,0.6367
# leg,bone_lesions,0.6846,0.4551
# chest,overlying_artifacts,0.3280,0.4648
# abdomen,renal_stones,0.8696,0.3340
# t-spine,postoperative_fusion_changes,0.9875,0.0403
# l-spine,sacroiliitis,0.0028,0.9727
# pelvis,sacralization_of_spine,0.4103,0.3984
# pelvis,iud,0.9984,0.0188
# l-spine,vacuum_disc_phenomenon,0.6514,0.5391
# abdomen,bowel_obstruction,0.8258,0.4766
# arm,enthesophytes,0.6943,0.4707
# leg,foreign_bodies,0.8554,0.2676
# abdomen,air_fluid_levels,0.8486,0.4414
# leg,meniscal_calcifications,0.8474,0.3105
# foot,joint_subluxation,0.4953,0.6445
# chest,atelectasis,0.5503,0.6523
# hand,buckle_fracture,0.9417,0.2812
# arm,joint_space_narrowing,0.5234,0.6055
# chest,mediastinal_shift,0.9765,0.0864
# leg,no_findings,0.6467,0.6602
# foot,fracture,0.6001,0.4473
# abdomen,support_devices,0.9049,0.3027
# chest,enlarged_mediastinum,0.5141,0.4512
# hand,degenerative_changes,0.4722,0.7266
# foot,osteomyelitis,0.8118,0.5078
# abdomen,surgical_clips_or_staples,0.8672,0.5625
# chest,osteoporosis,0.3083,0.7422
# foot,accessory_ossicles,0.0791,0.7812
# l-spine,pars_interarticularis_defects,0.5690,0.4766
# leg,support_devices,0.9788,0.0496
# l-spine,spondylosis,0.0381,0.8047
# t-spine,degenerative_changes,0.6042,0.5664
# hand,bone_lesions,0.2156,0.6484
# arm,tendinous_calcifications,0.5070,0.5938
# hand,ossicles,0.4089,0.6992
# t-spine,intervertebral_disc_narrowing,0.2634,0.7344
# pelvis,arthritis,0.5014,0.6641
# chest,subcutaneous_emphysema,0.9556,0.0549
# c-spine,neural_foraminal_narrowing,0.6963,0.7461
# chest,pulmonary_edema,0.9103,0.3691
# arm,support_devices,0.9457,0.1260
# chest,tracheal_deviation,0.4987,0.3887
# t-spine,support_devices,0.9030,0.3281
# foot,support_devices,0.9732,0.0618
# pelvis,degenerative_changes,0.4047,0.6250
# head,support_devices,0.7322,0.2031
# chest,diaphragmatic_eventration,0.7457,0.3965
# t-spine,spondylosis,0.0146,0.9180
# hand,soft_tissue_swelling,0.2296,0.6719
# c-spine,osteophytes,0.0349,0.8086
# chest,foreign_bodies,0.8879,0.1279
# l-spine,osteophytes,0.1259,0.7578
# chest,bronchiectasis,0.7153,0.3691
# chest,interstitial_lung_disease_(ild),0.4197,0.6445
# leg,enthesophytes,0.4406,0.7070
# t-spine,aortic_calcifications,0.0089,0.9766
# foot,subcutaneous_gas,0.8882,0.3164
# abdomen,constipation,0.2976,0.7578
# chest,consolidation,0.7766,0.5664
# c-spine,calcifications,0.1381,0.7070
# t-spine,no_findings,0.4951,0.7148
# hand,rarefaction,0.4792,0.6992
# chest,emphysema,0.6412,0.5938
# arm,ossicles,0.3175,0.6797
# leg,fracture,0.8100,0.2988
# foot,dislocation,0.8701,0.3105
# foot,enthesophytes,0.7165,0.5781
# hand,dislocation,0.7188,0.4375
# chest,hyperinflation,0.5123,0.6758
# c-spine,carotid_calcifications,0.9178,0.3594
# foot,hallux_valgus,0.8298,0.4043
# arm,joint_subluxation,0.3210,0.6523
# c-spine,listhesis,0.0007,0.6992
# hand,amputation,0.8417,0.2158
# chest,no_findings,0.5625,0.6562
# t-spine,kyphosis,0.5231,0.4980
# hand,support_devices,0.9554,0.1211
# hand,arthritic_changes,0.7021,0.6094
# arm,soft_tissue_swelling,0.5893,0.6289
# chest,fibrosis,0.6620,0.5781
# chest,scoliosis,0.7336,0.5234
# leg,joint_space_narrowing,0.6047,0.6172
# pelvis,subchondral_cyst,0.7195,0.3906
# l-spine,schmorl's_node,,
# abdomen,abnormal_calcifications,0.1603,0.7305
# pelvis,fracture,0.8267,0.3984
# pelvis,bony_mineralization,0.3418,0.7109
# c-spine,uncovertebral_joint_arthrosis,0.0347,0.8047
# pelvis,stool,0.6620,0.5703
# c-spine,kyphosis,0.4013,0.4980
# leg,intra-articular_bodies,0.6496,0.5703
# hand,foreign_bodies,0.7583,0.4102
# l-spine,bony_mineralization,0.3670,0.6836
# chest,pleural_plaque,0.9164,0.1484
# c-spine,bony_mineralization,0.4092,0.4551
# foot,degenerative_changes,0.2587,0.7383
# pelvis,pelvic_vascular_calcifications,0.7290,0.5508
# leg,tendinous_calcifications,0.4157,0.5391
# pelvis,pelvic_tilt,0.8998,0.1201
# foot,os_trigonum,0.5625,0.4238
# hand,bony_mineralization,0.5049,0.7539
# leg,degenerative_changes,0.2382,0.7500
# chest,bronchitis,0.2394,0.7383
# hand,fracture,0.7219,0.4297
# leg,soft_tissue_swelling,0.3684,0.6484
# leg,subcutaneous_gas,0.9705,0.1455
# head,no_findings,0.1231,0.6719
# foot,bone_lesions,0.3493,0.4629
# hand,joint_space_narrowing,0.4686,0.7305
# chest,pleural_thickening,0.5717,0.6211
# chest,cardiomegaly,0.8529,0.4707
# leg,patellar_tracking_abnormalities,0.2994,0.6289
# arm,bony_mineralization,0.2255,0.7578
# chest,mass_nodule,0.4718,0.6289
# foot,edema,0.2308,0.6953
# leg,rarefaction,0.4236,0.6719
# pelvis,no_findings,0.3572,0.6875
# c-spine,spondylosis,0.0574,0.7656
# chest,calcified_granuloma,0.8152,0.3281
# leg,joint_subluxation,0.4432,0.5156
# pelvis,urologic_stent,0.9938,0.0194
# pelvis,enthesopathy,0.4788,0.4180
# pelvis,bone_lesions,0.4711,0.6211
# foot,ossicles,0.1642,0.8203
# t-spine,detroconvex,0.1729,0.7812
# head,fracture,0.4158,0.5742
# pelvis,support_devices,0.9223,0.3203
# t-spine,osteophytes,0.0385,0.7734
# foot,no_findings,0.4269,0.7422
# foot,joint_effusion,0.5032,0.6055
# chest,venous_congestion,0.8308,0.4785
# chest,pacemaker_leads,0.9959,0.0103
# pelvis,femoral_acetabular_impingement,0.3462,0.5938
# foot,periosteal_reaction,0.2458,0.7305
# hand,no_findings,0.5374,0.6484
# chest,pneumonia,0.6766,0.5742
# c-spine,scoliosis,0.0462,0.8789
# abdomen,ureteral_stents,0.9937,0.0159
# arm,fat_pad_signs_suggesting_joint_effusion,0.7882,0.4863
# leg,soft_tissue_calcifications,0.7384,0.5508
# abdomen,calcified_phleboliths,0.4225,0.7266
# c-spine,support_devices,0.9671,0.0913
# l-spine,facet_joint_arthropathy,0.1508,0.7773

# %%
dict = {}
for ti in threshold_info:
    if ti["body_part"] not in dict:
        dict[ti["body_part"]] = {}
    dict[ti["body_part"]][ti["label"]] = ti["threshold"]

print(dict)
# Out:
# {'arm': {'fracture': 0.349609375, 'foreign_bodies': 0.3984375, 'arthritic_changes': 0.72265625, 'bone_lesions': 0.53125, 'no_findings': 0.671875, 'soft_tissue_calcifications': 0.76171875, 'degenerative_changes': 0.71484375, 'osteophytes': 0.68359375, 'subcutaneous_gas': 0.09814453125, 'dislocation': 0.2578125, 'joint_effusion': 0.44140625, 'rarefaction': 0.703125, 'acromioclavicular_joint_separation': 0.51953125, 'rotator_cuff_calcific_tendinitis': 0.416015625, 'enthesophytes': 0.470703125, 'joint_space_narrowing': 0.60546875, 'tendinous_calcifications': 0.59375, 'support_devices': 0.1259765625, 'ossicles': 0.6796875, 'joint_subluxation': 0.65234375, 'soft_tissue_swelling': 0.62890625, 'bony_mineralization': 0.7578125, 'fat_pad_signs_suggesting_joint_effusion': 0.486328125}, 'hand': {'tendon_avulsion_fractures': 0.66796875, 'ulnar_variance': 0.89453125, 'osteophytes': 0.7265625, 'erosive_change': 0.5390625, 'soft_tissue_calcifications': 0.5, 'nonunion': 0.30859375, 'scaphoid_fracture': 0.53515625, 'growth_plate_abnormalities': 0.578125, 'joint_subluxation': 0.54296875, 'buckle_fracture': 0.28125, 'degenerative_changes': 0.7265625, 'bone_lesions': 0.6484375, 'ossicles': 0.69921875, 'soft_tissue_swelling': 0.671875, 'rarefaction': 0.69921875, 'dislocation': 0.4375, 'amputation': 0.2158203125, 'support_devices': 0.12109375, 'arthritic_changes': 0.609375, 'foreign_bodies': 0.41015625, 'bony_mineralization': 0.75390625, 'fracture': 0.4296875, 'joint_space_narrowing': 0.73046875, 'no_findings': 0.6484375}, 'l-spine': {'support_devices': 0.384765625, 'spina_bifida_occulta': 0.5625, 'vertebral_height_loss': 0.65625, 'postoperative_fusion_changes': 0.0194091796875, 'fracture': 0.984375, 'scoliosis': 0.54296875, 'straightening': 0.70703125, 'intervertebral_disc_narrowing': 0.72265625, 'lumbarization_of_s1': 0.9140625, 'aortic_calcifications': 0.7109375, 'spondylolisthesis': 0.55859375, 'transitional_vertebrae': 0.63671875, 'no_findings': 0.74609375, 'spinal_canal_narrowing': 0.88671875, 'degenerative_changes': 0.62890625, 'lordosis': 0.8046875, 'lateral_curvature': 0.8828125, 'spondylolysis': 0.3203125, 'sacralization_of_l5': 0.7265625, 'sacroiliitis': 0.97265625, 'vacuum_disc_phenomenon': 0.5390625, 'pars_interarticularis_defects': 0.4765625, 'spondylosis': 0.8046875, 'osteophytes': 0.7578125, "schmorl's_node": 0.5, 'bony_mineralization': 0.68359375, 'facet_joint_arthropathy': 0.77734375}, 'abdomen': {'no_findings': 0.70703125, 'iud': 0.0272216796875, 'bowel_dilation': 0.451171875, 'uterine_fibroids': 0.09423828125, 'ileus': 0.6640625, 'ureteral_calculi': 0.62890625, 'colonic_distension': 0.5234375, 'free_air': 0.53125, 'abnormal_gas_patterns': 0.76171875, 'stool': 0.609375, 'degenerative_changes': 0.7265625, 'gallstones': 0.28125, 'foreign_bodies': 0.33203125, 'renal_stones': 0.333984375, 'bowel_obstruction': 0.4765625, 'air_fluid_levels': 0.44140625, 'support_devices': 0.302734375, 'surgical_clips_or_staples': 0.5625, 'constipation': 0.7578125, 'abnormal_calcifications': 0.73046875, 'ureteral_stents': 0.015869140625, 'calcified_phleboliths': 0.7265625}, 'chest': {'enlarged_pulmonary_artery': 0.453125, 'aortic_elongation_enlargement': 0.6015625, 'fracture': 0.51953125, 'pneumonitis': 0.66015625, 'adenopathy': 0.3828125, 'cardiac_devices': 0.0673828125, 'pneumothorax': 0.275390625, 'scarring': 0.68359375, 'arthritis': 0.32421875, 'costophrenic_angle_blunting': 0.58203125, 'tortuous_aorta': 0.7265625, 'diaphragmatic_elevation': 0.39453125, 'hernia': 0.16015625, 'airspace_opacity': 0.59375, 'perihilar_opacity': 0.55859375, 'granuloma': 0.443359375, 'covid-19': 0.189453125, 'sarcoidosis': 0.169921875, 'pleural_effusion': 0.2080078125, 'calcification': 0.671875, 'lung_volume_loss': 0.59765625, 'post-surgical_changes': 0.330078125, 'asthma': 0.443359375, 'support_devices': 0.45703125, 'degenerative_changes': 0.6875, 'congestive_heart_failure': 0.34765625, 'hiatal_hernia': 0.0927734375, 'flattening_of_the_hemi_diaphragm': 0.6953125, 'overlyi ...
